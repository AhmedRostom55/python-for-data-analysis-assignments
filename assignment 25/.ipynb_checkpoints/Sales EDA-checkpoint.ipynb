# %%
import numpy as np
import pandas as pd
import seaborn as sns

sns.set(rc={'figure.figsize': [9, 9]}, font_scale=1.2)

# %% [markdown]
# # Questions
#
# - Profit = cash - taxes (0.14)
# - Analyize all sales profit
# - What is the profit for each weekday
# - What is the profit from each city

# %%
df = pd.read_csv('Sales.csv')
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       295665          Macbook Pro Laptop                1      1700$
# 1       295666          LG Washing Machine                1     600.0$
# 2       295667        USB-C Charging Cable                1     11.95$
# 3       295668            27in FHD Monitor                1    149.99$
# 4       295669        USB-C Charging Cable                1     11.95$
# ...        ...                         ...              ...        ...
# 25112   319666    Lightning Charging Cable                1     14.95$
# 25113   319667       AA Batteries (4-pack)                2      3.84$
# 25114   319668             Vareebadd Phone                1       400$
# 25115   319669            Wired Headphones                1     11.99$
# 25116   319670  Bose SoundSport Headphones                1     99.99$
#
#            Order Date                        Purchase Address
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301
# ...               ...                                     ...
# 25112  12/11/19 20:58  14 Madison St, San Francisco, CA 94016
# 25113  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 25114  12/09/19 06:43        273 Wilson St, Seattle, WA 98101
# 25115  12/03/19 10:39          778 River St, Dallas, TX 75001
# 25116  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001
#
# [25117 rows x 6 columns]

# %% [markdown]
# ## 1. Distniguesh features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25117 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          25037 non-null  object
#  1   Product           25037 non-null  object
#  2   Quantity Ordered  25037 non-null  object
#  3   Price Each        25117 non-null  object
#  4   Order Date        25037 non-null  object
#  5   Purchase Address  25037 non-null  object
# dtypes: object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# ## 2. Data cleaning
#
# **Problems**
#
# - Numerical
#     - Quantity Ordered is not numerical
#     - Price Each not numerical
# - Categorical
#     - Product columns has 'Product' value

# %%
for v in df['Quantity Ordered'].unique():
    print(v)
# Out:
# 1
# 2
# 4
# 3
# Quantity Ordered
# nan
# 7
# 5
# 6

# %%
def fix_qty(qty_str):
    try:
        return int(qty_str)
    except:
        return np.nan
        

df['Quantity Ordered'] = df['Quantity Ordered'].apply(fix_qty)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25117 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          25037 non-null  object
#  1   Product           25037 non-null  object
#  2   Quantity Ordered  24989 non-null  float64
#  3   Price Each        25117 non-null  object
#  4   Order Date        25037 non-null  object
#  5   Purchase Address  25037 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 1.1+ MB

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered Price Each  \
# 0       295665          Macbook Pro Laptop               1.0      1700$
# 1       295666          LG Washing Machine               1.0     600.0$
# 2       295667        USB-C Charging Cable               1.0     11.95$
# 3       295668            27in FHD Monitor               1.0    149.99$
# 4       295669        USB-C Charging Cable               1.0     11.95$
# ...        ...                         ...               ...        ...
# 25112   319666    Lightning Charging Cable               1.0     14.95$
# 25113   319667       AA Batteries (4-pack)               2.0      3.84$
# 25114   319668             Vareebadd Phone               1.0       400$
# 25115   319669            Wired Headphones               1.0     11.99$
# 25116   319670  Bose SoundSport Headphones               1.0     99.99$
#
#            Order Date                        Purchase Address
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301
# ...               ...                                     ...
# 25112  12/11/19 20:58  14 Madison St, San Francisco, CA 94016
# 25113  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 25114  12/09/19 06:43        273 Wilson St, Seattle, WA 98101
# 25115  12/03/19 10:39          778 River St, Dallas, TX 75001
# 25116  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001
#
# [25117 rows x 6 columns]

# %%
for v in df['Price Each'].unique():
    print(v)
# Out:
# 1700$
# 600.0$
# 11.95$
# 149.99$
# 3.84$
# 99.99$
# 2.99$
# 999.99$
# 14.95$
# 600$
# 11.99$
# 150$
# 400$
# 700$
# 109.99$
# 379.99$
# 300$
# 389.99$
# Price Each$
# nan$

# %%
def fix_price_each(price_str):
    try:
        return float(price_str[:-1])
    except:
        return np.nan
    
df['Price Each'] = df['Price Each'].apply(fix_price_each)
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       295665          Macbook Pro Laptop               1.0     1700.00
# 1       295666          LG Washing Machine               1.0      600.00
# 2       295667        USB-C Charging Cable               1.0       11.95
# 3       295668            27in FHD Monitor               1.0      149.99
# 4       295669        USB-C Charging Cable               1.0       11.95
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable               1.0       14.95
# 25113   319667       AA Batteries (4-pack)               2.0        3.84
# 25114   319668             Vareebadd Phone               1.0      400.00
# 25115   319669            Wired Headphones               1.0       11.99
# 25116   319670  Bose SoundSport Headphones               1.0       99.99
#
#            Order Date                        Purchase Address
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301
# ...               ...                                     ...
# 25112  12/11/19 20:58  14 Madison St, San Francisco, CA 94016
# 25113  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 25114  12/09/19 06:43        273 Wilson St, Seattle, WA 98101
# 25115  12/03/19 10:39          778 River St, Dallas, TX 75001
# 25116  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001
#
# [25117 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25117 entries, 0 to 25116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          25037 non-null  object
#  1   Product           25037 non-null  object
#  2   Quantity Ordered  24989 non-null  float64
#  3   Price Each        24989 non-null  float64
#  4   Order Date        25037 non-null  object
#  5   Purchase Address  25037 non-null  object
# dtypes: float64(2), object(4)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        Quantity Ordered    Price Each
# count      24989.000000  24989.000000
# mean           1.125335    183.845650
# std            0.445414    333.077037
# min            1.000000      2.990000
# 25%            1.000000     11.950000
# 50%            1.000000     14.950000
# 75%            1.000000    150.000000
# max            7.000000   1700.000000

# %%
for p in df['Product'].unique():
    print(p)
# Out:
# Macbook Pro Laptop
# LG Washing Machine
# USB-C Charging Cable
# 27in FHD Monitor
# AA Batteries (4-pack)
# Bose SoundSport Headphones
# AAA Batteries (4-pack)
# ThinkPad Laptop
# Lightning Charging Cable
# Google Phone
# Wired Headphones
# Apple Airpods Headphones
# Vareebadd Phone
# iPhone
# 20in Monitor
# 34in Ultrawide Monitor
# Flatscreen TV
# 27in 4K Gaming Monitor
# nan
# LG Dryer

# %%
idx = df[  df['Product'] == 'Product'  ].index
idx
# Out:
# Int64Index([  254,   705,  1101,  2875,  3708,  3793,  3812,  4218,  5143,
#              5293,  6608,  6752,  7367,  7704,  7781,  8094, 10417, 11522,
#             11545, 11616, 12336, 12516, 12673, 13161, 16573, 16787, 17012,
#             17085, 18648, 19074, 19326, 19478, 19580, 19709, 20041, 20318,
#             20398, 20549, 20986, 21148, 21549, 22054, 22375, 23198, 23337,
#             23748, 24192, 24222],
#            dtype='int64')

# %%
df.drop(idx, axis=0, inplace=True)

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       295665          Macbook Pro Laptop               1.0     1700.00
# 1       295666          LG Washing Machine               1.0      600.00
# 2       295667        USB-C Charging Cable               1.0       11.95
# 3       295668            27in FHD Monitor               1.0      149.99
# 4       295669        USB-C Charging Cable               1.0       11.95
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable               1.0       14.95
# 25113   319667       AA Batteries (4-pack)               2.0        3.84
# 25114   319668             Vareebadd Phone               1.0      400.00
# 25115   319669            Wired Headphones               1.0       11.99
# 25116   319670  Bose SoundSport Headphones               1.0       99.99
#
#            Order Date                        Purchase Address
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301
# ...               ...                                     ...
# 25112  12/11/19 20:58  14 Madison St, San Francisco, CA 94016
# 25113  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 25114  12/09/19 06:43        273 Wilson St, Seattle, WA 98101
# 25115  12/03/19 10:39          778 River St, Dallas, TX 75001
# 25116  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001
#
# [25069 rows x 6 columns]

# %% [markdown]
# # Missing Values

# %%
df.isna().sum()
# Out:
# Order ID            80
# Product             80
# Quantity Ordered    80
# Price Each          80
# Order Date          80
# Purchase Address    80
# dtype: int64

# %%
df.shape
# Out:
# (25069, 6)

# %%
df.isna().mean() * 100
# Out:
# Order ID            0.319119
# Product             0.319119
# Quantity Ordered    0.319119
# Price Each          0.319119
# Order Date          0.319119
# Purchase Address    0.319119
# dtype: float64

# %%
df.dropna(axis=0, inplace=True)

# %%
df.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %% [markdown]
# # Handle Duplicated values

# %%
df[ df.duplicated() ]
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 440     296081               Flatscreen TV               1.0      300.00
# 1735    297311  Bose SoundSport Headphones               1.0       99.99
# 2822    298358    Apple Airpods Headphones               1.0      150.00
# 3131    298657    Lightning Charging Cable               1.0       14.95
# 3377    298883            Wired Headphones               1.0       11.99
# 3486    298988            Wired Headphones               1.0       11.99
# 4650    300085       AA Batteries (4-pack)               1.0        3.84
# 4686    300119            Wired Headphones               1.0       11.99
# 4696    300127            Wired Headphones               1.0       11.99
# 6320    301693      AAA Batteries (4-pack)               1.0        2.99
# 6411    301780       AA Batteries (4-pack)               1.0        3.84
# 7530    302846    Lightning Charging Cable               1.0       14.95
# 8510    303777    Apple Airpods Headphones               1.0      150.00
# 9136    304375    Lightning Charging Cable               1.0       14.95
# 9298    304531            Wired Headphones               1.0       11.99
# 9542    304761        USB-C Charging Cable               1.0       11.95
# 10232   305423            Wired Headphones               1.0       11.99
# 10630   305804      34in Ultrawide Monitor               1.0      379.99
# 10760   305928             ThinkPad Laptop               1.0      999.99
# 10789   305954  Bose SoundSport Headphones               1.0       99.99
# 11158   306308               Flatscreen TV               1.0      300.00
# 11313   306458      27in 4K Gaming Monitor               1.0      389.99
# 11342   306485    Lightning Charging Cable               1.0       14.95
# 12008   307114    Apple Airpods Headphones               1.0      150.00
# 12780   307861    Lightning Charging Cable               1.0       14.95
# 12845   307923    Lightning Charging Cable               1.0       14.95
# 13306   308362      AAA Batteries (4-pack)               1.0        2.99
# 13633   308671      27in 4K Gaming Monitor               1.0      389.99
# 13983   309008    Apple Airpods Headphones               1.0      150.00
# 14024   309045    Apple Airpods Headphones               1.0      150.00
# 15554   310524  Bose SoundSport Headphones               1.0       99.99
# 17956   312825  Bose SoundSport Headphones               1.0       99.99
# 18577   313410            Wired Headphones               1.0       11.99
# 18907   313728            Wired Headphones               1.0       11.99
# 19831   314614       AA Batteries (4-pack)               1.0        3.84
# 19894   314675       AA Batteries (4-pack)               1.0        3.84
# 20452   315204            Wired Headphones               1.0       11.99
# 21240   315955             ThinkPad Laptop               1.0      999.99
# 21467   316173      AAA Batteries (4-pack)               1.0        2.99
# 23352   317971       AA Batteries (4-pack)               1.0        3.84
#
#            Order Date                          Purchase Address
# 440    12/30/19 16:52           970 Sunset St, Austin, TX 73301
# 1735   12/07/19 07:30      858 Willow St, Los Angeles, CA 90001
# 2822   12/04/19 15:57       482 8th St, San Francisco, CA 94016
# 3131   12/01/19 18:22            428 12th St, Atlanta, GA 30301
# 3377   12/28/19 18:07      516 Willow St, Los Angeles, CA 90001
# 3486   12/26/19 16:11              528 8th St, Austin, TX 73301
# 4650   12/17/19 14:01           601 Spruce St, Boston, MA 02215
# 4686   12/30/19 13:22         533 Jackson St, Seattle, WA 98101
# 4696   12/10/19 08:55           385 Center St, Dallas, TX 75001
# 6320   12/20/19 16:44    536 Spruce St, San Francisco, CA 94016
# 6411   12/09/19 00:54     985 South St, San Francisco, CA 94016
# 7530   12/22/19 18:54              489 9th St, Boston, MA 02215
# 8510   12/30/19 15:35   75 Washington St, Los Angeles, CA 90001
# 9136   12/13/19 00:38       272 North St, Los Angeles, CA 90001
# 9298   12/27/19 00:44     306 Jackson St, Los Angeles, CA 90001
# 9542   12/22/19 09:51       506 8th St, San Francisco, CA 94016
# 10232  12/31/19 10:58  702 Chestnut St, San Francisco, CA 94016
# 10630  12/15/19 21:53      445 Main St, San Francisco, CA 94016
# 10760  12/08/19 16:33       637 North St, Los Angeles, CA 90001
# 10789  12/13/19 11:57             289 Pine St, Boston, MA 02215
# 11158  12/13/19 18:00            960 Hill St, Seattle, WA 98101
# 11313  12/22/19 11:27            641 West St, Atlanta, GA 30301
# 11342  12/01/19 21:57       337 9th St, San Francisco, CA 94016
# 12008  12/13/19 16:17          512 Maple St, Portland, OR 97035
# 12780  12/29/19 13:01    124 Cherry St, San Francisco, CA 94016
# 12845  12/07/19 07:56        526 13th St, Los Angeles, CA 90001
# 13306  12/31/19 10:18      914 Pine St, San Francisco, CA 94016
# 13633  12/28/19 10:52   773 Johnson St, San Francisco, CA 94016
# 13983  12/23/19 22:13             161 Pine St, Austin, TX 73301
# 14024  12/14/19 20:00  358 Chestnut St, New York City, NY 10001
# 15554  12/21/19 10:58            319 8th St, Portland, OR 97035
# 17956  12/03/19 23:33       615 1st St, New York City, NY 10001
# 18577  12/27/19 19:47        6 Hill St, San Francisco, CA 94016
# 18907  12/28/19 14:40       872 7th St, New York City, NY 10001
# 19831  12/02/19 14:47       20 Lake St, San Francisco, CA 94016
# 19894  12/26/19 09:01      927 13th St, San Francisco, CA 94016
# 20452  12/12/19 12:41       680 6th St, San Francisco, CA 94016
# 21240  12/26/19 17:28        588 Chestnut St, Seattle, WA 98101
# 21467  12/22/19 22:44         907 Sunset St, Portland, OR 97035
# 23352  12/17/19 18:39  250 Chestnut St, San Francisco, CA 94016

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       295665          Macbook Pro Laptop               1.0     1700.00
# 1       295666          LG Washing Machine               1.0      600.00
# 2       295667        USB-C Charging Cable               1.0       11.95
# 3       295668            27in FHD Monitor               1.0      149.99
# 4       295669        USB-C Charging Cable               1.0       11.95
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable               1.0       14.95
# 25113   319667       AA Batteries (4-pack)               2.0        3.84
# 25114   319668             Vareebadd Phone               1.0      400.00
# 25115   319669            Wired Headphones               1.0       11.99
# 25116   319670  Bose SoundSport Headphones               1.0       99.99
#
#            Order Date                        Purchase Address
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301
# ...               ...                                     ...
# 25112  12/11/19 20:58  14 Madison St, San Francisco, CA 94016
# 25113  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 25114  12/09/19 06:43        273 Wilson St, Seattle, WA 98101
# 25115  12/03/19 10:39          778 River St, Dallas, TX 75001
# 25116  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001
#
# [24949 rows x 6 columns]

# %% [markdown]
# # Handle Outliers

# %%
# !pip install datasist

# %%
from datasist.structdata import detect_outliers

# %%
idx = detect_outliers(df, 0, ['Price Each', 'Quantity Ordered'])
outliers = df.loc[idx]
clean = df.drop(idx, axis=0)

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       295665          Macbook Pro Laptop               1.0     1700.00
# 1       295666          LG Washing Machine               1.0      600.00
# 2       295667        USB-C Charging Cable               1.0       11.95
# 3       295668            27in FHD Monitor               1.0      149.99
# 4       295669        USB-C Charging Cable               1.0       11.95
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable               1.0       14.95
# 25113   319667       AA Batteries (4-pack)               2.0        3.84
# 25114   319668             Vareebadd Phone               1.0      400.00
# 25115   319669            Wired Headphones               1.0       11.99
# 25116   319670  Bose SoundSport Headphones               1.0       99.99
#
#            Order Date                        Purchase Address
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301
# ...               ...                                     ...
# 25112  12/11/19 20:58  14 Madison St, San Francisco, CA 94016
# 25113  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 25114  12/09/19 06:43        273 Wilson St, Seattle, WA 98101
# 25115  12/03/19 10:39          778 River St, Dallas, TX 75001
# 25116  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001
#
# [24949 rows x 6 columns]

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Profit
# Profit = cash - taxes (0.14)

# %%
def get_profit(row):
    qty = row['Quantity Ordered']
    price = row['Price Each']
    cash = qty * price
    taxes = cash * 0.14
    profit = cash - taxes
    return profit
    


df['Profit'] = df.apply(get_profit, axis=1)
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       295665          Macbook Pro Laptop               1.0     1700.00
# 1       295666          LG Washing Machine               1.0      600.00
# 2       295667        USB-C Charging Cable               1.0       11.95
# 3       295668            27in FHD Monitor               1.0      149.99
# 4       295669        USB-C Charging Cable               1.0       11.95
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable               1.0       14.95
# 25113   319667       AA Batteries (4-pack)               2.0        3.84
# 25114   319668             Vareebadd Phone               1.0      400.00
# 25115   319669            Wired Headphones               1.0       11.99
# 25116   319670  Bose SoundSport Headphones               1.0       99.99
#
#            Order Date                        Purchase Address     Profit
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001  1462.0000
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001   516.0000
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001    10.2770
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016   128.9914
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301    10.2770
# ...               ...                                     ...        ...
# 25112  12/11/19 20:58  14 Madison St, San Francisco, CA 94016    12.8570
# 25113  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001     6.6048
# 25114  12/09/19 06:43        273 Wilson St, Seattle, WA 98101   344.0000
# 25115  12/03/19 10:39          778 River St, Dallas, TX 75001    10.3114
# 25116  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001    85.9914
#
# [24949 rows x 7 columns]

# %%
def get_city(address):
    try:
        return address.split(', ')[1]
    except:
        return np.nan
    

# df['City'] = df['Purchase Address'].apply(lambda address: address.split(', ')[1])

df['City'] = df['Purchase Address'].apply(get_city)
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       295665          Macbook Pro Laptop               1.0     1700.00
# 1       295666          LG Washing Machine               1.0      600.00
# 2       295667        USB-C Charging Cable               1.0       11.95
# 3       295668            27in FHD Monitor               1.0      149.99
# 4       295669        USB-C Charging Cable               1.0       11.95
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable               1.0       14.95
# 25113   319667       AA Batteries (4-pack)               2.0        3.84
# 25114   319668             Vareebadd Phone               1.0      400.00
# 25115   319669            Wired Headphones               1.0       11.99
# 25116   319670  Bose SoundSport Headphones               1.0       99.99
#
#            Order Date                        Purchase Address     Profit  \
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001  1462.0000
# 1      12/29/19 07:03     562 2nd St, New York City, NY 10001   516.0000
# 2      12/12/19 18:21    277 Main St, New York City, NY 10001    10.2770
# 3      12/22/19 15:13     410 6th St, San Francisco, CA 94016   128.9914
# 4      12/18/19 12:38           43 Hill St, Atlanta, GA 30301    10.2770
# ...               ...                                     ...        ...
# 25112  12/11/19 20:58  14 Madison St, San Francisco, CA 94016    12.8570
# 25113  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001     6.6048
# 25114  12/09/19 06:43        273 Wilson St, Seattle, WA 98101   344.0000
# 25115  12/03/19 10:39          778 River St, Dallas, TX 75001    10.3114
# 25116  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001    85.9914
#
#                 City
# 0      New York City
# 1      New York City
# 2      New York City
# 3      San Francisco
# 4            Atlanta
# ...              ...
# 25112  San Francisco
# 25113    Los Angeles
# 25114        Seattle
# 25115         Dallas
# 25116    Los Angeles
#
# [24949 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24949 entries, 0 to 25116
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          24949 non-null  object
#  1   Product           24949 non-null  object
#  2   Quantity Ordered  24949 non-null  float64
#  3   Price Each        24949 non-null  float64
#  4   Order Date        24949 non-null  object
#  5   Purchase Address  24949 non-null  object
#  6   Profit            24949 non-null  float64
#  7   City              24949 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 2.3+ MB

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%m/%d/%y %H:%M', errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24949 entries, 0 to 25116
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          24949 non-null  object
#  1   Product           24949 non-null  object
#  2   Quantity Ordered  24949 non-null  float64
#  3   Price Each        24949 non-null  float64
#  4   Order Date        24949 non-null  datetime64[ns]
#  5   Purchase Address  24949 non-null  object
#  6   Profit            24949 non-null  float64
#  7   City              24949 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 2.3+ MB

# %%
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       295665          Macbook Pro Laptop               1.0     1700.00
# 1       295666          LG Washing Machine               1.0      600.00
# 2       295667        USB-C Charging Cable               1.0       11.95
# 3       295668            27in FHD Monitor               1.0      149.99
# 4       295669        USB-C Charging Cable               1.0       11.95
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable               1.0       14.95
# 25113   319667       AA Batteries (4-pack)               2.0        3.84
# 25114   319668             Vareebadd Phone               1.0      400.00
# 25115   319669            Wired Headphones               1.0       11.99
# 25116   319670  Bose SoundSport Headphones               1.0       99.99
#
#                Order Date                        Purchase Address     Profit  \
# 0     2019-12-30 00:01:00  136 Church St, New York City, NY 10001  1462.0000
# 1     2019-12-29 07:03:00     562 2nd St, New York City, NY 10001   516.0000
# 2     2019-12-12 18:21:00    277 Main St, New York City, NY 10001    10.2770
# 3     2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016   128.9914
# 4     2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301    10.2770
# ...                   ...                                     ...        ...
# 25112 2019-12-11 20:58:00  14 Madison St, San Francisco, CA 94016    12.8570
# 25113 2019-12-01 12:01:00    549 Willow St, Los Angeles, CA 90001     6.6048
# 25114 2019-12-09 06:43:00        273 Wilson St, Seattle, WA 98101   344.0000
# 25115 2019-12-03 10:39:00          778 River St, Dallas, TX 75001    10.3114
# 25116 2019-12-21 21:45:00  747 Chestnut St, Los Angeles, CA 90001    85.9914
#
#                 City
# 0      New York City
# 1      New York City
# 2      New York City
# 3      San Francisco
# 4            Atlanta
# ...              ...
# 25112  San Francisco
# 25113    Los Angeles
# 25114        Seattle
# 25115         Dallas
# 25116    Los Angeles
#
# [24949 rows x 8 columns]

# %%
df['Weekday'] = df['Order Date'].dt.day_name()
df
# Out:
#       Order ID                     Product  Quantity Ordered  Price Each  \
# 0       295665          Macbook Pro Laptop               1.0     1700.00
# 1       295666          LG Washing Machine               1.0      600.00
# 2       295667        USB-C Charging Cable               1.0       11.95
# 3       295668            27in FHD Monitor               1.0      149.99
# 4       295669        USB-C Charging Cable               1.0       11.95
# ...        ...                         ...               ...         ...
# 25112   319666    Lightning Charging Cable               1.0       14.95
# 25113   319667       AA Batteries (4-pack)               2.0        3.84
# 25114   319668             Vareebadd Phone               1.0      400.00
# 25115   319669            Wired Headphones               1.0       11.99
# 25116   319670  Bose SoundSport Headphones               1.0       99.99
#
#                Order Date                        Purchase Address     Profit  \
# 0     2019-12-30 00:01:00  136 Church St, New York City, NY 10001  1462.0000
# 1     2019-12-29 07:03:00     562 2nd St, New York City, NY 10001   516.0000
# 2     2019-12-12 18:21:00    277 Main St, New York City, NY 10001    10.2770
# 3     2019-12-22 15:13:00     410 6th St, San Francisco, CA 94016   128.9914
# 4     2019-12-18 12:38:00           43 Hill St, Atlanta, GA 30301    10.2770
# ...                   ...                                     ...        ...
# 25112 2019-12-11 20:58:00  14 Madison St, San Francisco, CA 94016    12.8570
# 25113 2019-12-01 12:01:00    549 Willow St, Los Angeles, CA 90001     6.6048
# 25114 2019-12-09 06:43:00        273 Wilson St, Seattle, WA 98101   344.0000
# 25115 2019-12-03 10:39:00          778 River St, Dallas, TX 75001    10.3114
# 25116 2019-12-21 21:45:00  747 Chestnut St, Los Angeles, CA 90001    85.9914
#
#                 City    Weekday
# 0      New York City     Monday
# 1      New York City     Sunday
# 2      New York City   Thursday
# 3      San Francisco     Sunday
# 4            Atlanta  Wednesday
# ...              ...        ...
# 25112  San Francisco  Wednesday
# 25113    Los Angeles     Sunday
# 25114        Seattle     Monday
# 25115         Dallas    Tuesday
# 25116    Los Angeles   Saturday
#
# [24949 rows x 9 columns]

# %%
df.describe()
# Out:
#        Quantity Ordered    Price Each        Profit
# count      24949.000000  24949.000000  24949.000000
# mean           1.125536    183.934078    159.051207
# std            0.445742    333.209044    286.406320
# min            1.000000      2.990000      2.571400
# 25%            1.000000     11.950000     10.277000
# 50%            1.000000     14.950000     12.857000
# 75%            1.000000    150.000000    129.000000
# max            7.000000   1700.000000   1462.000000

# %%
sns.displot(x='Profit', data=clean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-7207d61f8050> in <module>
# ----> 1 sns.displot(x='Profit', data=clean)
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2147     p = _DistributionFacetPlotter(
#    2148         data=data,
# -> 2149         variables=_DistributionFacetPlotter.get_semantics(locals())
#    2150     )
#    2151
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\distributions.py in __init__(self, data, variables)
#     107     ):
#     108
# --> 109         super().__init__(data=data, variables=variables)
#     110
#     111     @property
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\_core.py in __init__(self, data, variables)
#     602     def __init__(self, data=None, variables={}):
#     603
# --> 604         self.assign_variables(data, variables)
#     605
#     606         for var, cls in self._semantic_mappings.items():
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\_core.py in assign_variables(self, data, variables)
#     666             self.input_format = "long"
#     667             plot_data, variables = self._assign_variables_longform(
# --> 668                 data, **variables,
#     669             )
#     670
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\seaborn\_core.py in _assign_variables_longform(self, data, **kwargs)
#     900
#     901                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 902                 raise ValueError(err)
#     903
#     904             else:
#
# ValueError: Could not interpret value `Profit` for parameter `x`

# %%
df.groupby('City').describe()['Profit']
# Out:
#                 count        mean         std     min     25%     50%    75%  \
# City
# Atlanta        1986.0  155.936417  279.487549  2.5714  10.277  12.857  129.0
# Austin         1347.0  149.280600  263.737717  2.5714  10.277  12.857  129.0
# Boston         2695.0  162.971525  288.810207  2.5714  10.277  12.857  129.0
# Dallas         2004.0  164.091879  291.101034  2.5714  10.277  12.857  129.0
# Los Angeles    3887.0  150.927911  271.654024  2.5714  10.277  12.857  129.0
# New York City  3405.0  163.507476  292.205229  2.5714  10.277  12.857  129.0
# Portland       1645.0  158.726347  295.086393  2.5714  10.277  12.857  129.0
# San Francisco  6006.0  158.637020  289.681308  2.5714  10.277  12.857  129.0
# Seattle        1974.0  168.222361  300.457807  2.5714  10.277  12.857  129.0
#
#                   max
# City
# Atlanta        1462.0
# Austin         1462.0
# Boston         1462.0
# Dallas         1462.0
# Los Angeles    1462.0
# New York City  1462.0
# Portland       1462.0
# San Francisco  1462.0
# Seattle        1462.0

# %%
sns.boxplot(x='Profit', y='City', data=df)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='City'>

# %%
df.groupby('City').sum()['Profit'].sort_values()
# Out:
# City
# Austin           201080.9688
# Portland         261104.8408
# Atlanta          309689.7238
# Dallas           328840.1264
# Seattle          332070.9400
# Boston           439208.2608
# New York City    556742.9558
# Los Angeles      586656.7916
# San Francisco    952773.9448
# Name: Profit, dtype: float64

# %%
sns.barplot(x='City', y='Profit', estimator=np.sum, data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='City', ylabel='Profit'>

# %%
df.groupby('Weekday').describe()['Profit']
# Out:
#             count        mean         std     min     25%     50%    75%  \
# Weekday
# Friday     3253.0  156.365092  279.925139  2.5714  10.277  12.857  129.0
# Monday     4068.0  161.312585  291.449124  2.5714  10.277  12.857  129.0
# Saturday   3166.0  154.732363  284.895012  2.5714  10.277  12.857  129.0
# Sunday     3976.0  158.689568  288.350740  2.5714  10.277  12.857  129.0
# Thursday   3239.0  154.234808  277.236734  2.5714  10.277  12.857  129.0
# Tuesday    4008.0  160.279365  287.206135  2.5714  10.277  12.857  129.0
# Wednesday  3239.0  166.870853  293.532301  2.5714  10.277  12.857  129.0
#
#               max
# Weekday
# Friday     1462.0
# Monday     1462.0
# Saturday   1462.0
# Sunday     1462.0
# Thursday   1462.0
# Tuesday    1462.0
# Wednesday  1462.0

# %%
sns.boxplot(x='Profit', y='Weekday', data=df)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Weekday'>

# %%
df.groupby('Weekday').sum()['Profit'].sort_values()
# Out:
# Weekday
# Saturday     489882.6600
# Thursday     499566.5438
# Friday       508655.6430
# Wednesday    540494.6920
# Sunday       630949.7242
# Tuesday      642399.6954
# Monday       656219.5944
# Name: Profit, dtype: float64

# %%
sns.barplot(x='Weekday', y='Profit', estimator=np.sum, data=df, palette='flare')
# Out:
# <AxesSubplot:xlabel='Weekday', ylabel='Profit'>

# %%
df.sort_values('Profit', ascending=False)
# Out:
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 0       295665      Macbook Pro Laptop               1.0     1700.00
# 6602    301962      Macbook Pro Laptop               1.0     1700.00
# 11728   306850      Macbook Pro Laptop               1.0     1700.00
# 22847   317489      Macbook Pro Laptop               1.0     1700.00
# 3002    298531      Macbook Pro Laptop               1.0     1700.00
# ...        ...                     ...               ...         ...
# 15738   310703  AAA Batteries (4-pack)               1.0        2.99
# 21235   315951  AAA Batteries (4-pack)               1.0        2.99
# 4934    300356  AAA Batteries (4-pack)               1.0        2.99
# 12927   308004  AAA Batteries (4-pack)               1.0        2.99
# 10136   305333  AAA Batteries (4-pack)               1.0        2.99
#
#                Order Date                          Purchase Address  \
# 0     2019-12-30 00:01:00    136 Church St, New York City, NY 10001
# 6602  2019-12-03 18:10:00   707 Hickory St, San Francisco, CA 94016
# 11728 2019-12-19 21:07:00      160 14th St, New York City, NY 10001
# 22847 2019-12-28 13:59:00      936 Hill St, San Francisco, CA 94016
# 3002  2019-12-04 19:16:00     344 Adams St, San Francisco, CA 94016
# ...                   ...                                       ...
# 15738 2019-12-18 17:02:00    628 Spruce St, San Francisco, CA 94016
# 21235 2019-12-20 11:52:00    598 Wilson St, San Francisco, CA 94016
# 4934  2019-12-30 18:27:00       15 Jefferson St, Portland, OR 97035
# 12927 2019-12-20 17:33:00  417 Chestnut St, San Francisco, CA 94016
# 10136 2019-12-23 09:53:00              437 8th St, Austin, TX 73301
#
#           Profit           City    Weekday
# 0      1462.0000  New York City     Monday
# 6602   1462.0000  San Francisco    Tuesday
# 11728  1462.0000  New York City   Thursday
# 22847  1462.0000  San Francisco   Saturday
# 3002   1462.0000  San Francisco  Wednesday
# ...          ...            ...        ...
# 15738     2.5714  San Francisco  Wednesday
# 21235     2.5714  San Francisco     Friday
# 4934      2.5714       Portland     Monday
# 12927     2.5714  San Francisco     Friday
# 10136     2.5714         Austin     Monday
#
# [24949 rows x 9 columns]

# %%
sales = df[  df['Product'] == 'ThinkPad Laptop'  ]
sales
# Out:
#       Order ID          Product  Quantity Ordered  Price Each  \
# 11      295676  ThinkPad Laptop               1.0      999.99
# 35      295697  ThinkPad Laptop               1.0      999.99
# 204     295852  ThinkPad Laptop               1.0      999.99
# 242     295890  ThinkPad Laptop               1.0      999.99
# 297     295941  ThinkPad Laptop               1.0      999.99
# ...        ...              ...               ...         ...
# 24902   319463  ThinkPad Laptop               1.0      999.99
# 24942   319503  ThinkPad Laptop               1.0      999.99
# 25039   319595  ThinkPad Laptop               1.0      999.99
# 25049   319604  ThinkPad Laptop               1.0      999.99
# 25110   319664  ThinkPad Laptop               1.0      999.99
#
#                Order Date                        Purchase Address    Profit  \
# 11    2019-12-28 17:19:00   410 Lincoln St, Los Angeles, CA 90001  859.9914
# 35    2019-12-15 07:38:00   742 River St, San Francisco, CA 94016  859.9914
# 204   2019-12-24 20:52:00    639 Sunset St, Los Angeles, CA 90001  859.9914
# 242   2019-12-05 11:59:00     254 Elm St, San Francisco, CA 94016  859.9914
# 297   2019-12-31 16:24:00       64 Dogwood St, Portland, OR 97035  859.9914
# ...                   ...                                     ...       ...
# 24902 2019-12-30 20:38:00  513 Spruce St, New York City, NY 10001  859.9914
# 24942 2019-12-28 00:49:00    148 Pine St, San Francisco, CA 94016  859.9914
# 25039 2019-12-31 22:38:00     788 6th St, San Francisco, CA 94016  859.9914
# 25049 2019-12-13 01:30:00    474 12th St, San Francisco, CA 94016  859.9914
# 25110 2019-12-30 01:06:00     767 2nd St, San Francisco, CA 94016  859.9914
#
#                 City   Weekday
# 11       Los Angeles  Saturday
# 35     San Francisco    Sunday
# 204      Los Angeles   Tuesday
# 242    San Francisco  Thursday
# 297         Portland   Tuesday
# ...              ...       ...
# 24902  New York City    Monday
# 24942  San Francisco  Saturday
# 25039  San Francisco   Tuesday
# 25049  San Francisco    Friday
# 25110  San Francisco    Monday
#
# [539 rows x 9 columns]
